# %% [markdown]
# <a href="https://colab.research.google.com/github/shravyanjalikadunoori-hub/flyrankML/blob/main/work/notebooks/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/shravyanjalikadunoori-hub/flyrankML/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
#  My Lane as an ML Task
#
# Lane: Ranking Signal Analysis
#
# Task Type: Ranking
#
# This project focuses on predicting the ranking of web pages based on search signals such as clicks, impressions, engagement, and other ranking features. The goal is to identify which pages are more likely to rank higher in search results and understand the factors that influence visibility.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
#  Target or Proxy
#
# Target:
# The model predicts the search ranking or visibility of a webpage.
#
# Proxy:
# The prediction is based on search signals such as clicks, impressions, CTR, and engagement metrics.
#
# The target comes from observed search performance data collected from the FlyRank dataset rather than a manually defined rule.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
#  Success Metric
#
# The success of the model will be measured using ranking evaluation metrics.
#
# Primary Metric:
# - NDCG (Normalized Discounted Cumulative Gain)
#
# Other Metrics:
# - Precision
# - Recall
# - Mean Reciprocal Rank (MRR)
#
# These metrics help evaluate how accurately the model ranks webpages based on their relevance and search visibility.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %% [markdown]
#  Unit of Analysis
#
# Each row in the dataset represents one webpage (or content page).
#
# Each webpage contains features such as clicks, impressions, CTR, engagement, and other search-related signals. The model uses these features to predict the webpage's search ranking.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# Why ML Beats a Fixed Rule
#
# Search ranking depends on many factors that interact in complex ways. A fixed rule cannot capture these relationships accurately.
#
# Machine Learning learns patterns from historical data and can adapt to different situations, making its predictions more accurate and scalable than manually written rules.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
